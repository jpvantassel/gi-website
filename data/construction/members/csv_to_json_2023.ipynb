# %% [markdown]
# # csv to json
#
# > Original Author: Joseph P. Vantassel
#
# > Edited by Cheng-Hsi Hsiao
#
# Convert cleaned `.csv` data to `.json`.

# %%
import json
import math

import pandas as pd

# %%
fname = "2023_fall_members"
#fname = "2020_member_responses_clean"
df = pd.read_csv(fname + ".csv")
df.head()
# Out:
#             Timestamp First Name     Last Name   UT EID  \
# 0   8/22/2023 9:19:02      Brent         Sordo  Bts2222
# 1   8/22/2023 9:28:00     Mehmet      Turkezer  mt39834
# 2   8/22/2023 9:35:04     Ashish      Govindan  aag4284
# 3  8/22/2023 10:09:38    Anusha   Vajapeyajula  av35875
# 4  8/22/2023 11:29:29     Sharen       Wallace  saw4373
#
#              UT email address What program are you in?  \
# 0           Bsordo@utexas.edu                      PhD
# 1  mehmet.turkezer@utexas.edu                      PhD
# 2       a.govindan@utexas.edu                       MS
# 3          anushav@utexas.edu                       MS
# 4        sawallace@utexas.edu                       MS
#
#   Do you plan to graduate this semester? What country are you from?  \
# 0                                     No              United States
# 1                                     No                     Turkey
# 2                                     No              United States
# 3                                    Yes                      India
# 4                                     No     British Virgin Islands
#
#   State (if applicable)     City Birth Date  \
# 0            California  Modesto      11/26
# 1                   NaN   Ankara       7/25
# 2                 Texas  Lubbock       8/31
# 3                   NaN      NaN       12/8
# 4                   NaN      NaN       3/13
#
#                                       Personal Photo  \
# 0                                                NaN
# 1  https://drive.google.com/open?id=1dVmHD1zPrRkX...
# 2  https://drive.google.com/open?id=1u6fGP9yvowec...
# 3  https://drive.google.com/open?id=1quMPNybzbLLN...
# 4                                                NaN
#
#                                             Bio Link
# 0                                                NaN
# 1                  https://linkedin.com/in/mturkezer
# 2  www.linkedin.com/in/ashish-govindan-eit-571868151
# 3  https://www.linkedin.com/in/anusha-vajapeyajulaa5
# 4               http://linkedin.com/in/sharenwallace

# %%
# create a clean version df
df['name'] = df['First Name'] + " " + df['Last Name']
df.rename(columns={'What program are you in?':'degree',
                   'What country are you from?':'country',
                   'State (if applicable)':'state',
                   'City':'city',
                   'Bio Link':'link'}, inplace=True)
df = df[['name','degree','country','state','city','link']]
df.sort_values(by=['name'], inplace=True)
df
# Out:
#                     name          degree                 country  \
# 14        A. Mert Kavala       MSc & PhD                  Turkey
# 20    Adityo Andikaputra              MS               Indonesia
# 23      Angel de la Cruz              MS           United States
# 24        Anthony  Matar              MS                 Lebanon
# 3   Anusha  Vajapeyajula              MS                   India
# 2        Ashish Govindan              MS           United States
# 0            Brent Sordo             PhD           United States
# 5          Carlos Acosta             PhD                Colombia
# 17       Cheng-Hsi Hsiao             PhD                  Taiwan
# 28          Chenghao Bai             PhD                   China
# 6           Chih-Yu Tung             PhD                  Taiwan
# 15            Dawie Marx             PhD            South Africa
# 11      Etienne Gonzalez             PhD                  Mexico
# 26      Fernando Ramirez              MS                  Mexico
# 18       Jeremy Goethals              MS           United States
# 25        Jorge Loaisiga              MS               Nicaragua
# 9         Jorge Zornberg       Professor          USA, Argentina
# 7          Julia Grasley             PhD           United States
# 27         Krishna Kumar  Not Applicable                   India
# 13     Leila  Roshanali              PhD                    Iran
# 1        Mehmet Turkezer             PhD                  Turkey
# 21       Omar  Abukassab       MSc & PhD                  Jordan
# 10         Shantel Ramlo              MS           United States
# 4         Sharen Wallace              MS  British Virgin Islands
# 8            Shuyi Zhang             PhD                   China
# 12            Sujin Park             PhD             South Korea
# 16           Will Pliska              MS           United States
# 22              Yiwei Ye             PhD                   China
# 19          Yongjin Choi             PhD             South Korea
#
#            state             city  \
# 14           NaN         Istanbul
# 20     West Java          Bandung
# 23         Texas           Austin
# 24           NaN           Beirut
# 3            NaN              NaN
# 2          Texas          Lubbock
# 0     California          Modesto
# 5            NaN              NaN
# 17           NaN           Taipei
# 28           NaN           Anqing
# 6            NaN         Taichung
# 15           NaN         Pretoria
# 11           NaN      Mexico City
# 26           NaN  San Luis Potosi
# 18         Texas          Houston
# 25           NaN          Managua
# 9            NaN              NaN
# 7          Texas  College Station
# 27    Tamil Nadu          Madurai
# 13           NaN           Shiraz
# 1            NaN           Ankara
# 21           NaN            Irbid
# 10  South Dakota        Brookings
# 4            NaN              NaN
# 8        Jiangxi          Ganzhou
# 12           NaN            Seoul
# 16    Washington          Seattle
# 22           NaN          Wenzhou
# 19           NaN            Busan
#
#                                                  link
# 14             https://www.linkedin.com/in/mertkavala
# 20  https://www.linkedin.com/in/adityo-muhammad-an...
# 23  https://www.linkedin.com/in/angel-de-la-cruz-9...
# 24  https://www.linkedin.com/in/anthony-matar-5465...
# 3   https://www.linkedin.com/in/anusha-vajapeyajulaa5
# 2   www.linkedin.com/in/ashish-govindan-eit-571868151
# 0                                                 NaN
# 5    https://sites.utexas.edu/zornberg/carlos-acosta/
# 17       https://www.linkedin.com/in/cheng-hsi-hsiao/
# 28  Linkedin: https://www.linkedin.com/in/chenghao...
# 6   https://www.linkedin.com/in/chih-yu-tung-sheldon/
# 15            https://www.linkedin.com/in/dawie-marx/
# 11       https://www.linkedin.com/in/etiennegonzalez/
# 26  https://www.linkedin.com/in/fernando-ramirez-e...
# 18  https://www.linkedin.com/me?trk=p_mwlite_my_ne...
# 25                           linkedin.com/in/loaisiga
# 9                  https://sites.utexas.edu/zornberg/
# 7   https://www.linkedin.com/in/julia-grasley-6b7a...
# 27                                                NaN
# 13                                                NaN
# 1                   https://linkedin.com/in/mturkezer
# 21                                                NaN
# 10          https://www.linkedin.com/in/shantelramlo/
# 4                http://linkedin.com/in/sharenwallace
# 8                                                 NaN
# 12  https://drive.google.com/file/d/1IVJEVAZj_Br5I...
# 16                                                NaN
# 22                                        yeyiwei.org
# 19          https://sites.google.com/view/geo-yjchoi/

# %%
path = "images/members/"
members = []
for index, line in df.iterrows():
    name, degree, country, state, city, link = line
    split_name  = name.split(" ")

    fname = split_name[0].lower()
    for _name in split_name[1:]:
        fname += "_" + _name.lower()
    fname += ".jpg"
    
    if isinstance(state, (float)):
        if math.isnan(state):
            state = ''
    if isinstance(city, (float)):
        if math.isnan(city):
            city = ''
    if isinstance(link, (float)):
        if math.isnan(link):
            link = None

    members.append({"name":name, "path":path + fname, "degree":degree, "country":country, "state":state, "city":city, "link":link})
        
with open("members.json", "w") as f:
    json.dump(members, f, indent=4)

# %%
len(members)
# Out:
# 19
