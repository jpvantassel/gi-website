# %% [markdown]
# # csv to json
#
# > Original Author: Joseph P. Vantassel
#
# > Edited by Cheng-Hsi Hsiao
#
# Convert cleaned `.csv` data to `.json`.

# %%
import json
import math
import pandas as pd

# %%
fname = "2024_fall_members"
#fname = "2020_member_responses_clean"
df = pd.read_csv(fname + ".csv")
df.head()
# Out:
#             Timestamp First Name  Last Name   UT EID  \
# 0  8/31/2024 12:35:22  Cheng-Hsi      Hsiao  ch49826
# 1  8/30/2024 15:15:26      Shuyi      Zhang   sz9898
# 2  8/30/2024 16:07:49     Taylor    Stinson   gts736
# 3  8/30/2024 17:15:33       Omar  Abukassab   ota328
# 4  8/30/2024 17:50:13     Leila   Roshanali  lr34966
#
#              UT email address What program are you in?  \
# 0          chhsiao@utexas.edu                      PhD
# 1      shuyi_zhang@utexas.edu                      PhD
# 2         tstinson@utexas.edu                      PhD
# 3         oakassab@utexas.edu                MSc & PhD
# 4  leila.roshanali@utexas.edu                       MS
#
#   What country are you from? State (if applicable)         City Birth Date  \
# 0                     Taiwan                   NaN       Taipei        9/8
# 1                      China                   NaN      Ganzhou      10/24
# 2              United States             Tennessee  Clarksville       3/12
# 3                     Jordan                   NaN        Irbid       8/18
# 4                       Iran                   NaN      Shiraz        6/16
#
#                                       Personal Photo  \
# 0  https://drive.google.com/open?id=1Sr8iLAPA0yqU...
# 1  https://drive.google.com/open?id=1EdwSEMUYpm0v...
# 2                                                NaN
# 3  https://drive.google.com/open?id=1U-1BJNO8X5Of...
# 4                                                NaN
#
#                                             Bio Link
# 0       https://www.linkedin.com/in/cheng-hsi-hsiao/
# 1  https://www.linkedin.com/in/shuyi-zhang-a50434...
# 2                                                NaN
# 3  https://www.linkedin.com/in/omar-abukassab-658...
# 4       https://www.linkedin.com/in/leila-roshanali/

# %%
# create a clean version df
# remove space
df['First Name'].replace(' ', '', regex=True, inplace=True)
df['Last Name'].replace(' ', '', regex=True, inplace=True)
df['name'] = df['First Name'] + " " + df['Last Name']
df.rename(columns={'What program are you in?':'degree',
                   'What country are you from?':'country',
                   'State (if applicable)':'state',
                   'City':'city',
                   'Bio Link':'link'}, inplace=True)
df = df[['name','degree','country','state','city','link']]
df.sort_values(by=['name'], inplace=True)
df
# Out:
#                      name     degree        country              state  \
# 16     AbhilashReddy Goli         MS          India                NaN
# 17          Ahmed Alsadah         MS   Saudi Arabia  Eastern province
# 5           Ashray Saxena        PhD          India                NaN
# 0         Cheng-Hsi Hsiao        PhD         Taiwan                NaN
# 7            Chenghao Bai        PhD          China                NaN
# 19           Chih-Yu Tung        PhD         TAIWAN                NaN
# 12        DesiNur Marlina         MS      Indonesia                NaN
# 11        Faisal Alotaibi        PhD   Saudi Arabia                NaN
# 18            Juan Ortega         MS       Colombia                NaN
# 9   KowshikKumar Thalluru         MS          India     Andhra Pradesh
# 4         Leila Roshanali         MS           Iran                NaN
# 6               Mahsa Nia        PhD           Iran                NaN
# 8        Miles Drazkowski        PhD  United States             Oregon
# 3          Omar Abukassab  MSc & PhD         Jordan                NaN
# 1             Shuyi Zhang        PhD          China                NaN
# 13       Stepan Tretiakov  MSc & PhD         Russia                NaN
# 10             Sujin Park        PhD    South Korea                NaN
# 2          Taylor Stinson        PhD  United States          Tennessee
# 15    Venkataraman Ramesh        PhD          India         Tamil Nadu
# 14         Yagizer Yalcin        PhD         Turkey                NaN
#
#              city                                               link
# 16      Hyderabad  https://www.linkedin.com/in/abhilash-reddy-gol...
# 17  Safwa - Qatif                                                NaN
# 5         Aligarh                                                NaN
# 0          Taipei       https://www.linkedin.com/in/cheng-hsi-hsiao/
# 7          Anqing  https://www.linkedin.com/in/chenghao-bai-8168b...
# 19       Taichung                                                NaN
# 12        Bandung  https://www.linkedin.com/in/desi-nur-marlina-b...
# 11         Riyadh  https://www.linkedin.com/in/faisal-alotaibi-52...
# 18        Bogotá   https://www.linkedin.com/in/juan-ortega-5b6581...
# 9         Nellore  https://www.linkedin.com/in/kowshik-kumar?utm_...
# 4         Shiraz        https://www.linkedin.com/in/leila-roshanali/
# 6          Tehran                                                NaN
# 8       Willamina  www.linkedin.com/in/miles-drazkowski-ei-eit-a8...
# 3           Irbid  https://www.linkedin.com/in/omar-abukassab-658...
# 1         Ganzhou  https://www.linkedin.com/in/shuyi-zhang-a50434...
# 13         Kurgan                                       Coming Soon
# 10          Seoul  https://drive.google.com/file/d/1rU4EhGuV3PVtx...
# 2     Clarksville                                                NaN
# 15         Trichy   https://www.linkedin.com/in/venkataraman-ramesh/
# 14         Ankara          https://www.linkedin.com/in/yagizeryalcin

# %%
path = "images/members/"
members = []
for index, line in df.iterrows():
    name, degree, country, state, city, link = line
    split_name  = name.split(" ")

    fname = split_name[0].lower()
    for _name in split_name[1:]:
        fname += "_" + _name.lower()
    fname += ".jpg"
    
    if isinstance(state, (float)):
        if math.isnan(state):
            state = ''
    if isinstance(city, (float)):
        if math.isnan(city):
            city = ''
    if isinstance(link, (float)):
        if math.isnan(link):
            link = None

    members.append({"name":name, "path":path + fname, "degree":degree, "country":country, "state":state, "city":city, "link":link})
        
with open("members.json", "w") as f:
    json.dump(members, f, indent=4)

# %%
# load faculty json
with open("../../faculty.json", "r") as f:
    faculty = json.load(f)

# %%
# merge faculty and members
members = faculty + members
# sort by name
members = sorted(members, key=lambda x: x["name"])
# save to members.json
with open("members.json", "w") as f:
    json.dump(members, f, indent=4)
print("done")
# Out:
# done

# %%
# overwrite the members.json file
#with open("members.json", "w") as f:
#    json.dump(members, f, indent=4)
